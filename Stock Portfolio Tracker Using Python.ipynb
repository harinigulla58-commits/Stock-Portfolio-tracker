# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
stock_prices = {
    "AAPL": 180,
    "TSLA": 250,
    "GOOGL": 140,
    "MSFT": 420,
    "AMZN": 170
}

# %%
portfolio = {}

n = int(input("Enter number of stocks: "))

for i in range(n):
    stock = input("Enter stock name: ").upper()
    quantity = int(input("Enter quantity: "))
    
    if stock in stock_prices:
        portfolio[stock] = quantity
    else:
        print("Stock not available")
# Out:
# Enter number of stocks:  3
# Enter stock name:  AAPL
# Enter quantity:  5
# Enter stock name:  TSLA
# Enter quantity:  2
# Enter stock name:  MSFT
# Enter quantity:  3

# %%
total_investment = 0

for stock, quantity in portfolio.items():
    
    investment = stock_prices[stock] * quantity
    
    print(stock, "=", investment)
    
    total_investment += investment

print("\nTotal Investment =", total_investment)
# Out:
# AAPL = 900
# TSLA = 500
# MSFT = 1260
#
# Total Investment = 2660

# %%
data = []

for stock, quantity in portfolio.items():
    
    value = stock_prices[stock] * quantity
    
    data.append([stock, quantity, stock_prices[stock], value])

df = pd.DataFrame(
    data,
    columns=["Stock", "Quantity", "Price", "Investment"]
)

print(df)
# Out:
#   Stock  Quantity  Price  Investment
# 0  AAPL         5    180         900
# 1  TSLA         2    250         500
# 2  MSFT         3    420        1260

# %%
df.to_csv("portfolio.csv", index=False)

print("Portfolio saved successfully!")
# Out:
# Portfolio saved successfully!

# %%
plt.figure(figsize=(8,5))

plt.bar(
    df["Stock"],
    df["Investment"]
)

plt.title("Stock Investment Comparison")
plt.xlabel("Stocks")
plt.ylabel("Investment Value")

plt.show()

# %%
plt.figure(figsize=(6,6))

plt.pie(
    df["Investment"],
    labels=df["Stock"],
    autopct='%1.1f%%'
)

plt.title("Portfolio Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.plot(
    df["Stock"],
    df["Investment"],
    marker='o'
)

plt.title("Stock Investment Trend")
plt.xlabel("Stocks")
plt.ylabel("Investment Value")

plt.grid(True)

plt.show()
